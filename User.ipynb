# %% [markdown]
# # Welcome

# %% [markdown]
# # This is a Ipy NoteBook , made for all those who want to master python

# %% [markdown]
# This note book was made stand alone with [binder](https://mybinder.org)

# %%
from matplotlib import pyplot as plt

# %%
plt.plot([0,1,2,3,4],[0,1,4,3,2])

# %% [markdown]
# ## The learning guide provided with this notebook was made by [Akuli](https://github.com/Akuli/python-tutorial)
# Many Thanks to him.

# %% [markdown]
# # So get ready to dive into the deep ocean of python
# # And Click [HERE](index.html)
